# %% [markdown]
# **Business Problem**
#
# IMDB is the biggest movie rating platform in the world. A significant proportion of users choose to watch movies only after checking ratings, the number of votes, and reviews of the movie on the IMDB platform. The data IMDB captures is critical to generate insights into what is the public's preference. Which genres make more money, and which genres have good ratings and still have lesser revenue?
#
# The insights generated from the dataset can be monetized as directors can create content viewers want. Once the movie is released, this dataset can also be used to predict the movie's revenue.
#
#
# Explore and analyze the dataset to generate findings and insights that drive revenue.

# %%
import pandas as pd #Importing pandas library

# %%
import numpy as np #Importing numpy library

# %%
#Importing movie dataset and storing in a variable

df=pd.read_csv(r"C:\Users\ACER NITRO\Desktop\Python\IMDBMovie.csv")

# %%
#Checking preview of raw data

df
# Out:
#        ID                    Title      Genre              Director  Year  \
# 0       1  Guardians of the Galaxy     Action            James Gunn  2014
# 1       2               Prometheus  Adventure          Ridley Scott  2012
# 2       3                    Split     Horror    M. Night Shyamalan  2016
# 3       4                     Sing  Animation  Christophe Lourdelet  2016
# 4       5            Suicide Squad     Action            David Ayer  2016
# ..    ...                      ...        ...                   ...   ...
# 995   996     Secret in Their Eyes      Crime             Billy Ray  2015
# 996   997          Hostel: Part II     Horror              Eli Roth  2007
# 997   998   Step Up 2: The Streets      Drama            Jon M. Chu  2008
# 998   999             Search Party  Adventure        Scot Armstrong  2014
# 999  1000               Nine Lives     Comedy      Barry Sonnenfeld  2016
#
#      Runtime_minutes  Rating   Votes  Revenue_millions
# 0                121     8.1  757074            333.13
# 1                124     7.0  485820            126.46
# 2                117     7.3  157606            138.12
# 3                108     7.2   60545            270.32
# 4                123     6.2  393727            325.02
# ..               ...     ...     ...               ...
# 995              111     6.2   27585               NaN
# 996               94     5.5   73152             17.54
# 997               98     6.2   70699             58.01
# 998               93     5.6    4881               NaN
# 999               87     5.3   12435             19.64
#
# [1000 rows x 9 columns]

# %%
df.describe()
# Out:
#                 ID         Year  Runtime_minutes       Rating         Votes  \
# count  1000.000000  1000.000000      1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000       113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962        18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000        66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000       100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000       111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000       123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000       191.000000     9.000000  1.791916e+06
#
#        Revenue_millions
# count        872.000000
# mean          82.956376
# std          103.253540
# min            0.000000
# 25%           13.270000
# 50%           47.985000
# 75%          113.715000
# max          936.630000

# %%
sum(df["Revenue_millions"].isnull()) ##Count of Null vales in revenue
# Out:
# 128

# %%
sum(df["Revenue_millions"]>75) ##Count of movies having revenue more tha 75 millions
# Out:
# 318

# %%
sum((df["Revenue_millions"]>50) & (df["Rating"]<7)) ## Count of movies having revenue more than 50 mil and rating less that 7
# Out:
# 211

# %%
rev_yr=df.groupby(by="Year",as_index=False)["Revenue_millions"].agg("sum") ## revenue/Year
rev_yr
# Out:
#     Year  Revenue_millions
# 0   2006           3624.46
# 1   2007           4306.23
# 2   2008           5053.22
# 3   2009           5292.26
# 4   2010           5989.65
# 5   2011           5431.96
# 6   2012           6910.29
# 7   2013           7666.72
# 8   2014           7997.40
# 9   2015           8854.12
# 10  2016          11211.65

# %%
## Storing all te movies released on 2015 with Adventure Genre

avg_rating=df[(df["Year"]==2015) & (df["Genre"]=="Adventure")]
avg_rating
# Out:
#       ID          Title      Genre                     Director  Year  \
# 102  103    The Martian  Adventure                 Ridley Scott  2015
# 129  130   The Revenant  Adventure  Alejandro González Iñárritu  2015
# 354  355      Insurgent  Adventure             Robert Schwentke  2015
# 409  410       Vacation  Adventure           John Francis Daley  2015
# 464  465     Goosebumps  Adventure                Rob Letterman  2015
# 513  514  Bone Tomahawk  Adventure              S. Craig Zahler  2015
# 565  566            Pan  Adventure                   Joe Wright  2015
# 667  668          Ted 2  Adventure              Seth MacFarlane  2015
# 967  968       The Walk  Adventure              Robert Zemeckis  2015
# 984  985            Max  Adventure                   Boaz Yakin  2015
#
#      Runtime_minutes  Rating   Votes  Revenue_millions
# 102              144     8.0  556097            228.43
# 129              156     8.0  499424            183.64
# 354              119     6.3  171970            130.00
# 409               99     6.1   74589             58.88
# 464              103     6.3   57602             80.02
# 513              132     7.1   47289             66.01
# 565              111     5.8   47804             34.96
# 667              115     6.3  136323             81.26
# 967              123     7.3   92378             10.14
# 984              111     6.8   21405             42.65

# %%
avg_rating["Rating"].mean() ## the average rating for the genre adventure in the year 2015
# Out:
# 6.8

# %%
df.loc[75:149,"Runtime_minutes"].mean().round(2) ## The average duration of movies in rows 75 to 150
# Out:
# 127.61

# %%
rev_yr.sort_values(by="Revenue_millions",ascending=False) ## Sorting the total revenue per year descending
# Out:
#     Year  Revenue_millions
# 10  2016          11211.65
# 9   2015           8854.12
# 8   2014           7997.40
# 7   2013           7666.72
# 6   2012           6910.29
# 4   2010           5989.65
# 5   2011           5431.96
# 3   2009           5292.26
# 2   2008           5053.22
# 1   2007           4306.23
# 0   2006           3624.46

# %%
df.loc[10:50:10,"Revenue_millions"] ## finding revenue from coloumn 10 to 50
# Out:
# 10    234.02
# 20      7.22
# 30     60.31
# 40     97.66
# 50    936.63
# Name: Revenue_millions, dtype: float64

# %%
sum((df["Genre"]=="Adventure") | (df["Genre"]=="Action") | (df["Genre"]=="Horror") | (df["Genre"]=="Crime")) ## movies with the genres ‘Adventure’, ‘Action’, ‘Horror’, and ‘Crime’
# Out:
# 485

# %% [markdown]
# **Data analysis:**
#
# Now that we have explored and understood the data, we want to create certain reports from the IMDB dataset. These reports will help the stakeholders analyze which type of movie makes more money. How does the rating of the movie affect the revenue of the movie?

# %%
## Cacculating avg Revenue & rating for every Genre 

rev_1=df.groupby(by="Genre",as_index=False).agg({"Votes":"mean","Revenue_millions":"mean","Rating":"mean"}).round(2)

# %%
rev_1
# Out:
#         Genre      Votes  Revenue_millions  Rating
# 0      Action  235948.58            122.09    6.59
# 1   Adventure  225669.32            113.45    6.91
# 2   Animation  208159.43            191.22    7.32
# 3   Biography  153060.72             55.95    7.32
# 4      Comedy  115640.19             51.58    6.49
# 5       Crime  150124.96             41.04    6.81
# 6       Drama  129445.13             35.87    6.95
# 7     Fantasy  106723.00             63.11    5.85
# 8      Horror   79435.41             39.95    5.87
# 9     Mystery  218672.00             64.38    6.88
# 10    Romance  104572.00             62.45    6.60
# 11     Sci-Fi   57450.00             42.64    4.97
# 12   Thriller   31156.80              0.32    5.96

# %%
## Calculatinf total Revenue per genre per Year and storing the data
rev_2=df.groupby(by=["Year","Genre"],as_index=False)["Revenue_millions"].agg("sum")
rev_2.rename(columns={"Revenue_millions":"Total_Revenue"},inplace=True)

# %%
rev_2
# Out:
#      Year      Genre  Total_Revenue
# 0    2006     Action        1664.01
# 1    2006  Adventure         112.55
# 2    2006  Animation         442.04
# 3    2006  Biography         178.55
# 4    2006     Comedy         323.07
# ..    ...        ...            ...
# 101  2016     Horror         469.47
# 102  2016    Mystery           0.00
# 103  2016    Romance           0.00
# 104  2016     Sci-Fi          20.76
# 105  2016   Thriller           0.00
#
# [106 rows x 3 columns]

# %%
df[df["Title"]=="Split"]["Genre"] ## Fininding the Genre of the movie Split
# Out:
# 2    Horror
# Name: Genre, dtype: object

# %%
rev_total=pd.merge(df,rev_2) ## Mearging the Dataframe with total revenue per genre per year under new df

# %%
rev_total
# Out:
#       ID                            Title    Genre           Director  Year  \
# 0      1          Guardians of the Galaxy   Action         James Gunn  2014
# 1     54                        John Wick   Action     Chad Stahelski  2014
# 2     66     Kingsman: The Secret Service   Action     Matthew Vaughn  2014
# 3    127  Transformers: Age of Extinction   Action        Michael Bay  2014
# 4    163       X-Men: Days of Future Past   Action       Bryan Singer  2014
# ..   ...                              ...      ...                ...   ...
# 995  851                               21    Crime     Robert Luketic  2008
# 996  859              The Hills Have Eyes   Horror      Alexandre Aja  2006
# 997  946                         Triangle  Fantasy  Christopher Smith  2009
# 998  974                         Scream 4   Horror         Wes Craven  2011
# 999  987              Final Destination 5   Horror       Steven Quale  2011
#
#      Runtime_minutes  Rating   Votes  Revenue_millions  Total_Revenue
# 0                121     8.1  757074            333.13        4458.07
# 1                101     7.2  321933             43.00        4458.07
# 2                129     7.7  440209            128.25        4458.07
# 3                165     5.7  255483            245.43        4458.07
# 4                132     8.0  552298            233.91        4458.07
# ..               ...     ...     ...               ...            ...
# 995              123     6.8  198395             81.16          81.16
# 996              107     6.4  136642             41.78          41.78
# 997               99     6.9   72533               NaN           0.00
# 998              111     6.2  108544             38.18          80.76
# 999               92     5.9   88000             42.58          80.76
#
# [1000 rows x 10 columns]

# %%
rev_2[rev_2["Year"]==2014] ## Total revenue for the Year 2014
# Out:
#     Year      Genre  Total_Revenue
# 74  2014     Action        4458.07
# 75  2014  Adventure         932.61
# 76  2014  Animation         707.40
# 77  2014  Biography         294.68
# 78  2014     Comedy         788.15
# 79  2014      Crime         317.46
# 80  2014      Drama         393.75
# 81  2014     Horror          98.98
# 82  2014    Mystery           5.98
# 83  2014   Thriller           0.32

# %%
rev_total=rev_total[rev_total["Revenue_millions"].notnull()] ## Fetching all the not null values im Revenue

# %%
## Calculating % Revenue as  Revenue of movie * 100 / (Total revenue of genre and year)

rev_total["% Revenue"]=rev_total.apply(lambda x: (x["Revenue_millions"]/x["Total_Revenue"])*100,axis=1)

# %%
rev_total
# Out:
#       ID                            Title    Genre        Director  Year  \
# 0      1          Guardians of the Galaxy   Action      James Gunn  2014
# 1     54                        John Wick   Action  Chad Stahelski  2014
# 2     66     Kingsman: The Secret Service   Action  Matthew Vaughn  2014
# 3    127  Transformers: Age of Extinction   Action     Michael Bay  2014
# 4    163       X-Men: Days of Future Past   Action    Bryan Singer  2014
# ..   ...                              ...      ...             ...   ...
# 994  836                         The Loft  Mystery   Erik Van Looy  2014
# 995  851                               21    Crime  Robert Luketic  2008
# 996  859              The Hills Have Eyes   Horror   Alexandre Aja  2006
# 998  974                         Scream 4   Horror      Wes Craven  2011
# 999  987              Final Destination 5   Horror    Steven Quale  2011
#
#      Runtime_minutes  Rating   Votes  Revenue_millions  Total_Revenue  \
# 0                121     8.1  757074            333.13        4458.07
# 1                101     7.2  321933             43.00        4458.07
# 2                129     7.7  440209            128.25        4458.07
# 3                165     5.7  255483            245.43        4458.07
# 4                132     8.0  552298            233.91        4458.07
# ..               ...     ...     ...               ...            ...
# 994              108     6.3   38804              5.98           5.98
# 995              123     6.8  198395             81.16          81.16
# 996              107     6.4  136642             41.78          41.78
# 998              111     6.2  108544             38.18          80.76
# 999               92     5.9   88000             42.58          80.76
#
#       % Revenue
# 0      7.472516
# 1      0.964543
# 2      2.876805
# 3      5.505297
# 4      5.246889
# ..          ...
# 994  100.000000
# 995  100.000000
# 996  100.000000
# 998   47.275879
# 999   52.724121
#
# [872 rows x 11 columns]

# %%
rev_total[rev_total["Title"]=="Split"] ## Revenue % for the film "Split"
# Out:
#     ID  Title   Genre            Director  Year  Runtime_minutes  Rating  \
# 40   3  Split  Horror  M. Night Shyamalan  2016              117     7.3
#
#      Votes  Revenue_millions  Total_Revenue  % Revenue
# 40  157606            138.12         469.47   29.42041

# %%
df
# Out:
#        ID                    Title      Genre              Director  Year  \
# 0       1  Guardians of the Galaxy     Action            James Gunn  2014
# 1       2               Prometheus  Adventure          Ridley Scott  2012
# 2       3                    Split     Horror    M. Night Shyamalan  2016
# 3       4                     Sing  Animation  Christophe Lourdelet  2016
# 4       5            Suicide Squad     Action            David Ayer  2016
# ..    ...                      ...        ...                   ...   ...
# 995   996     Secret in Their Eyes      Crime             Billy Ray  2015
# 996   997          Hostel: Part II     Horror              Eli Roth  2007
# 997   998   Step Up 2: The Streets      Drama            Jon M. Chu  2008
# 998   999             Search Party  Adventure        Scot Armstrong  2014
# 999  1000               Nine Lives     Comedy      Barry Sonnenfeld  2016
#
#      Runtime_minutes  Rating   Votes  Revenue_millions
# 0                121     8.1  757074            333.13
# 1                124     7.0  485820            126.46
# 2                117     7.3  157606            138.12
# 3                108     7.2   60545            270.32
# 4                123     6.2  393727            325.02
# ..               ...     ...     ...               ...
# 995              111     6.2   27585               NaN
# 996               94     5.5   73152             17.54
# 997               98     6.2   70699             58.01
# 998               93     5.6    4881               NaN
# 999               87     5.3   12435             19.64
#
# [1000 rows x 9 columns]

# %%
max_votes = df["Votes"].max() #Calculates the maximum value in the "Votes" 
min_votes = df["Votes"].min()# Calculates the minimum value in the "Votes"
df["Votes_norm"]= df.apply(lambda x: (x["Votes"]-min_votes)*10/(max_votes-min_votes), axis=1) ## Votes_norm is [Votes - min(Votes)]*10/[max(votes) - min(votes)

# %%
df["Votes_norm"].mean().round(2) ## Avg Votes norm
# Out:
# 0.95

# %%
df["Total_rating"]=df["Votes_norm"]+df["Rating"] ## Total_rating is ‘Rating’+ ‘Votes_norm’.

# %%
df["Total_rating"].max() ## max Total Rating
# Out:
# 19.0

# %%
df["Title"][df["Total_rating"]==df["Total_rating"].max()] ## Movie with the Max Total Ratings
# Out:
# 54    The Dark Knight
# Name: Title, dtype: object

# %%
df
# Out:
#        ID                    Title      Genre              Director  Year  \
# 0       1  Guardians of the Galaxy     Action            James Gunn  2014
# 1       2               Prometheus  Adventure          Ridley Scott  2012
# 2       3                    Split     Horror    M. Night Shyamalan  2016
# 3       4                     Sing  Animation  Christophe Lourdelet  2016
# 4       5            Suicide Squad     Action            David Ayer  2016
# ..    ...                      ...        ...                   ...   ...
# 995   996     Secret in Their Eyes      Crime             Billy Ray  2015
# 996   997          Hostel: Part II     Horror              Eli Roth  2007
# 997   998   Step Up 2: The Streets      Drama            Jon M. Chu  2008
# 998   999             Search Party  Adventure        Scot Armstrong  2014
# 999  1000               Nine Lives     Comedy      Barry Sonnenfeld  2016
#
#      Runtime_minutes  Rating   Votes  Revenue_millions  Votes_norm  \
# 0                121     8.1  757074            333.13    4.224745
# 1                124     7.0  485820            126.46    2.710928
# 2                117     7.3  157606            138.12    0.879229
# 3                108     7.2   60545            270.32    0.337550
# 4                123     6.2  393727            325.02    2.196975
# ..               ...     ...     ...               ...         ...
# 995              111     6.2   27585               NaN    0.153606
# 996               94     5.5   73152             17.54    0.407907
# 997               98     6.2   70699             58.01    0.394217
# 998               93     5.6    4881               NaN    0.026899
# 999               87     5.3   12435             19.64    0.069057
#
#      Total_rating
# 0       12.324745
# 1        9.710928
# 2        8.179229
# 3        7.537550
# 4        8.396975
# ..            ...
# 995      6.353606
# 996      5.907907
# 997      6.594217
# 998      5.626899
# 999      5.369057
#
# [1000 rows x 11 columns]

# %%
direct=df.groupby(by="Director",as_index=False)["Genre"].nunique()## Count of genre

# %%
sum(direct["Genre"]==direct["Genre"].max()) ## How many directors have created movies in the highest number of genres
# Out:
# 2

# %%
h=df["Revenue_millions"].max() ## Storing Max Revenue

# %%
 ## Adding Bins on 10 to Revenue
    
df["Revenue_bins"]=pd.cut(x=df["Revenue_millions"],bins=[0,50,100,150],labels=["0-50","51-100","101-150"])

# %%
df
# Out:
#        ID                    Title      Genre              Director  Year  \
# 0       1  Guardians of the Galaxy     Action            James Gunn  2014
# 1       2               Prometheus  Adventure          Ridley Scott  2012
# 2       3                    Split     Horror    M. Night Shyamalan  2016
# 3       4                     Sing  Animation  Christophe Lourdelet  2016
# 4       5            Suicide Squad     Action            David Ayer  2016
# ..    ...                      ...        ...                   ...   ...
# 995   996     Secret in Their Eyes      Crime             Billy Ray  2015
# 996   997          Hostel: Part II     Horror              Eli Roth  2007
# 997   998   Step Up 2: The Streets      Drama            Jon M. Chu  2008
# 998   999             Search Party  Adventure        Scot Armstrong  2014
# 999  1000               Nine Lives     Comedy      Barry Sonnenfeld  2016
#
#      Runtime_minutes  Rating   Votes  Revenue_millions  Votes_norm  \
# 0                121     8.1  757074            333.13    4.224745
# 1                124     7.0  485820            126.46    2.710928
# 2                117     7.3  157606            138.12    0.879229
# 3                108     7.2   60545            270.32    0.337550
# 4                123     6.2  393727            325.02    2.196975
# ..               ...     ...     ...               ...         ...
# 995              111     6.2   27585               NaN    0.153606
# 996               94     5.5   73152             17.54    0.407907
# 997               98     6.2   70699             58.01    0.394217
# 998               93     5.6    4881               NaN    0.026899
# 999               87     5.3   12435             19.64    0.069057
#
#      Total_rating Revenue_bins
# 0       12.324745          NaN
# 1        9.710928      101-150
# 2        8.179229      101-150
# 3        7.537550          NaN
# 4        8.396975          NaN
# ..            ...          ...
# 995      6.353606          NaN
# 996      5.907907         0-50
# 997      6.594217       51-100
# 998      5.626899          NaN
# 999      5.369057         0-50
#
# [1000 rows x 12 columns]
